# %% [markdown]
# <h1><span style="color:blue">NAIVE BAYES</span></h1>

# %% [markdown]
# La probabilidad de que un patron pertenezca a la clase **C**,
#
# sabiendo que tiene X1,x2,x3,...xn
#
# Asi ya lo podemos comenzar a trabajar.
#
# Sinembargo, debo hacer una serie de asumciones para poder generar un modelo de Bayes

# %%
from IPython.display import Image
Image(filename='img/15.PNG')

# %%
ASUMIR la independencia absoluta de las variables.

# %%
from IPython.display import Image
Image(filename='img/16.PNG')

# %% [markdown]
# Programa para detectar si hay SPAM en el inbox
#
# Vamos a tener una serie de terminos que normalmente están presentes.
#
# El Y del dataset será binario(Si es SPAM o NO)

# %%
from IPython.display import Image
Image(filename='img/17.PNG')

# %% [markdown]
# No hay dependencia entre unos terminos y los otros ------INDEPENDENCIA

# %%
from IPython.display import Image
Image(filename='img/18.PNG')
