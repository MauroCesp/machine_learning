# %% [markdown]
# <h1><span style="color:blue">KNN (vecino más cercano) </span></h1>

# %% [markdown]
# Esta basado en la similaridad por lo cual se calcula la distancia.
#
# Se puede utilizar la distancia **Euclidea**
#
# No tiene fase de entrenamiento, porque funciona guardando partes en memoria
#
# Se puede aplicar a **clasificacion** y **Regresion**

# %%
from IPython.display import Image
Image(filename='img/6.PNG')

# %%
from IPython.display import Image
Image(filename='img/7.PNG')

# %% [markdown]
# En este modelo es muy importante realizar un **reescalado de datos**

# %%
import numpy, random, time
from sklearn.model_selection import train_test_split

# Este es la libreria en python que permite el KNN
from sklearn.neighbors import KNeighborsClassifier

import pandas as pd

from sklearn.metrics import roc_auc_score, confusion_matrix, accuracy_score, balanced_accuracy_score

from sklearn.preprocessing import StandardScaler

import sklearn

# %% [markdown]
# Voy a utilizar este dataset de clasificacion binaria. Pero solo tengo que cambiar el dataset a IRIS(multiclase)
#
# El resto del codigo queda exactametne igual porque el algoritmo detecta en el **FIT** si la variable independiente es multiclase o no.

# %%
file = 'iris.csv'

data = pd.read_csv(file)

data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
# 150           5.3          4.3           2.1          0.5     setosa

# %% [markdown]
# #### Primero
#
# Divido los datos entre los inputs y el output

# %%
X = data[data.columns[:-1]]
Y = data['class']

# %% [markdown]
# #### Segundo
#
# Divido con la funcion **train_test_split**. Esto es más para juguetear con los datos , no para realizar experimentos sistematizados
#
# Le paso todo el conjunto de datos
#
# Ento me divide en 70% para entrenamiento y 30% para test
#
# Vamos a continuar utilizando <span style="color:red"> **X_train** y **y_train** </span> en los modelos de validación

# %%
seed = random.randint(0,10)

# Aqui genero 4 dataframes nuevos (2 train, 2 test) 
#Usamos el 30% de instancias para test y 70% para train
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=seed)

# %% [markdown]
# **Terecero**
#
# Reescalamos los datos de entrada
#
# Generamos el modelo de escalado mediante los datos de entrenamiento.
#
# Y después transformamos los datos de entranamiento (X_train) mediante **stdScaler**
#
# Aqui es **SUPER IMPORTANTE** realizarlo. Puede ser un MinMax or un Standard

# %%
scaler = MinMaxScaler().fit(X_train)

scaler.fit(X_train)

X_train = scaler.transform(X_train)

# %% [markdown]
# Aqui le indico a mi modleo que deseo averiguar la distancia euclidea, la similaridad entre patrones
#
# Y tambien definimos **K** que son los vecinos que definimos.

# %%
modelo = KNeighborsClassifier(n_neighbors=7, metric='euclidean')

# %% [markdown]
# Ahora entreno el modelo mediante FIT

# %%
modelo.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=7)

# %% [markdown]
# Utilizo los valores de prueba para realizar la prediccion

# %%
X_test = scaler.transform(X_test)

pred = modelo.predict(X_test)
# Out:
# c:\users\mauro.cespedesaraya\appdata\local\programs\python\python38\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Aqui tenemos que revisar si en un dataset balaceado o no para obtener la metrica correcta.

# %%
print(confusion_matrix(y_test, pred))
# Out:
# [[1919  547]
#  [1081  257]]

# %%
print(balanced_accuracy_score(y_test, pred))
# Out:
# 0.48513051036700017
